# %% [markdown]
# <a href="https://colab.research.google.com/github/risyando/PM2/blob/main/Homework%20%20Risyando.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv('Sample-Superstore - Orders.csv')  # Gantilah path-nya sesuai file kamu
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
# Sorting data berdasarkan kolom 'Sales' dari yang terkecil ke yang terbesar
sorted_sales_df = df.sort_values(by='Sales', ascending=True)

# Tampilkan 10 data teratas setelah sorting
sorted_sales_df.head(10)
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 4101    4102  US-2017-102288   6/19/2017   6/23/2017  Standard Class
# 9292    9293  CA-2017-124114    3/2/2017    3/2/2017        Same Day
# 8658    8659  CA-2016-168361   6/21/2016   6/25/2016  Standard Class
# 4711    4712  CA-2014-112403   3/31/2014   3/31/2014        Same Day
# 2106    2107  US-2014-152723   9/26/2014   9/26/2014        Same Day
# 7548    7549  CA-2014-103492  10/10/2014  10/15/2014  Standard Class
# 8033    8034  CA-2015-119690   6/25/2015   6/28/2015     First Class
# 2761    2762  CA-2017-126536  10/12/2017  10/14/2017     First Class
# 8024    8025  CA-2014-129189   7/21/2014   7/25/2014  Standard Class
# 1332    1333  CA-2014-122567   2/16/2014   2/21/2014  Standard Class
#
#      Customer ID     Customer Name      Segment        Country           City  \
# 4101    ZC-21910  Zuschuss Carroll     Consumer  United States        Houston
# ...

# %%
# Membaca ulang file untuk memastikan df tersedia
df = pd.read_csv("Sample-Superstore - Orders.csv")

# 2.a. Mengambil kolom Ship Mode, Segment, Sales, dan Profit
filtered_df_a = df[['Ship Mode', 'Segment', 'Sales', 'Profit']]

# 2.b. Mengambil data dengan Ship Mode 'Standard Class' dari City 'Detroit' dan 'Atlanta'
filtered_df_b = df[
    (df['Ship Mode'] == 'Standard Class') &
    (df['City'].isin(['Detroit', 'Atlanta']))
][['Order Date', 'Ship Mode', 'Segment', 'City']]

filtered_df_a.head(), filtered_df_b.head()
# Out:
# (        Ship Mode    Segment     Sales    Profit
#  0    Second Class   Consumer  261.9600   41.9136
#  1    Second Class   Consumer  731.9400  219.5820
#  2    Second Class  Corporate   14.6200    6.8714
#  3  Standard Class   Consumer  957.5775 -383.0310
#  4  Standard Class   Consumer   22.3680    2.5164,
#      Order Date       Ship Mode    Segment     City
#  225   8/9/2015  Standard Class  Corporate  Detroit
#  226   8/9/2015  Standard Class  Corporate  Detroit
#  227   8/9/2015  Standard Class  Corporate  Detroit
#  506  3/16/2015  Standard Class   Consumer  Atlanta
#  507  3/16/2015  Standard Class   Consumer  Atlanta)
